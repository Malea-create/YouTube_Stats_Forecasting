# %% [markdown]
# # Data Preprocessing
#
# Dieses Notebook wendet ein Data Cleaning auf diese Daten an und unterteilt diese in länder- und jahresspezifische csv-files, die im Ordner "Data/preprocessed_data" gespeichert werden.

# %% [markdown]
# # Install the requirements
#
# Laden aller Packages die für das Projekt benötigt werden

# %%
! pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: absl-py==1.3.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: aiohttp==3.8.3 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 2)) (3.8.3)
# Requirement already satisfied: aiosignal==1.2.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 3)) (1.2.0)
# Requirement already satisfied: alt-profanity-check==1.2.2 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 4)) (1.2.2)
# Requirement already satisfied: anyio==3.7.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 5)) (3.7.0)
# Requirement already satisfied: appdirs==1.4.4 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 6)) (1.4.4)
# Requirement already satisfied: appnope==0.1.3 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 7)) (0.1.3)
# Requirement already satisfied: asttokens==2.2.1 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 8)) (2.2.1)
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 9)) (1.6.3)
# Requirement already satisfied: async-timeout==4.0.2 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 10)) (4.0.2)
# Requirement already satisfied: attrs==22.1.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 11)) (22.1.0)
# Requirement already satisfied: autokeras==1.1.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 12)) (1.1.0)
# Requirement already satisfied: backcall==0.2.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 13)) (0.2.0)
# Requirement already satisfied: backoff==2.2.1 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 14)) (2.2.1)
# Requirement already satisfied: backports.functools-lru-cache==1.6.4 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 15)) (1.6.4)
# Requirement already satisfied: better-profanity==0.7.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 16)) (0.7.0)
# Requirement already satisfied: black==23.3.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 17)) (23.3.0)
# Requirement already satisfied: bleach==6.0.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 18)) (6.0.0)
# Requirement already satisfied: blinker==1.4 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 19)) (1.4)
# Requirement already satisfied: blis==0.7.9 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 20)) (0.7.9)
# Requirement already satisfied: brotlipy==0.7.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 21)) (0.7.0)
# Requirement already satisfied: cachetools==4.2.2 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 22)) (4.2.2)
# Requirement already satisfied: catalogue==2.0.8 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 23)) (2.0.8)
# Requirement already satisfied: certifi==2023.5.7 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 24)) (2023.5.7)
# Requirement already satisfied: cffi==1.15.1 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 25)) (1.15.1)
# Requirement already satisfied: charset-normalizer==2.0.4 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 26)) (2.0.4)
# Requirement already satisfied: click==8.0.4 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 27)) (8.0.4)
# Requirement already satisfied: colorama==0.4.6 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 28)) (0.4.6)
# Requirement already satisfied: comm==0.1.3 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 29)) (0.1.3)
# Requirement already satisfied: confection==0.0.4 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 30)) (0.0.4)
# Requirement already satisfied: contourpy==1.0.7 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 31)) (1.0.7)
# Requirement already satisfied: cryptography==39.0.1 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 32)) (39.0.1)
# Requirement already satisfied: cvxopt==1.3.1 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 33)) (1.3.1)
# Requirement already satisfied: cycler==0.11.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 34)) (0.11.0)
# Requirement already satisfied: cymem==2.0.7 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 35)) (2.0.7)
# Requirement already satisfied: dataclasses==0.8 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 36)) (0.8)
# Requirement already satisfied: debugpy==1.6.7 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 37)) (1.6.7)
# Requirement already satisfied: decorator==5.1.1 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 38)) (5.1.1)
# Requirement already satisfied: docopt==0.6.2 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 39)) (0.6.2)
# Requirement already satisfied: efficientnet==1.1.1 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 40)) (1.1.1)
# Requirement already satisfied: exceptiongroup==1.1.1 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 41)) (1.1.1)
# Requirement already satisfied: executing==1.2.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 42)) (1.2.0)
# Requirement already satisfied: fastai==2.7.12 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 43)) (2.7.12)
# Requirement already satisfied: fastapi==0.96.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 44)) (0.96.0)
# Requirement already satisfied: fastcore==1.5.29 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 45)) (1.5.29)
# Requirement already satisfied: fastdownload==0.0.7 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 46)) (0.0.7)
# Requirement already satisfied: fastjsonschema==2.17.1 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 47)) (2.17.1)
# Requirement already satisfied: fastprogress==1.0.3 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 48)) (1.0.3)
# Requirement already satisfied: filelock==3.12.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 49)) (3.12.0)
# Requirement already satisfied: flatbuffers==2.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 50)) (2.0)
# Requirement already satisfied: fonttools==4.39.4 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 51)) (4.39.4)
# Requirement already satisfied: frozenlist==1.3.3 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 52)) (1.3.3)
# Requirement already satisfied: gast==0.4.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 53)) (0.4.0)
# Requirement already satisfied: google-api-core==2.11.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 54)) (2.11.0)
# Requirement already satisfied: google-api-python-client==2.88.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 55)) (2.88.0)
# Requirement already satisfied: google-auth==2.19.1 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 56)) (2.19.1)
# Requirement already satisfied: google-auth-httplib2==0.1.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 57)) (0.1.0)
# Requirement already satisfied: google-auth-oauthlib==0.4.6 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 58)) (0.4.6)
# Requirement already satisfied: google-pasta==0.2.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 59)) (0.2.0)
# Requirement already satisfied: googleapis-common-protos==1.59.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 60)) (1.59.0)
# Requirement already satisfied: grpcio==1.42.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 61)) (1.42.0)
# Requirement already satisfied: gunicorn==20.1.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 62)) (20.1.0)
# Requirement already satisfied: h5py==3.7.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 63)) (3.7.0)
# Requirement already satisfied: hatebase==1.0.3 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 64)) (1.0.3)
# Requirement already satisfied: httplib2==0.22.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 65)) (0.22.0)
# Requirement already satisfied: idna==3.4 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 66)) (3.4)
# Requirement already satisfied: image-tabular==0.0.6 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 67)) (0.0.6)
# Requirement already satisfied: imageio==2.31.1 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 68)) (2.31.1)
# Requirement already satisfied: importlib-metadata==6.6.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 69)) (6.6.0)
# Requirement already satisfied: ipykernel==6.23.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 70)) (6.23.0)
# Requirement already satisfied: ipython==8.13.2 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 71)) (8.13.2)
# Requirement already satisfied: itsdangerous==2.1.2 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 72)) (2.1.2)
# Requirement already satisfied: jedi==0.18.2 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 73)) (0.18.2)
# Requirement already satisfied: Jinja2==3.1.2 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 74)) (3.1.2)
# Requirement already satisfied: joblib==1.2.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 75)) (1.2.0)
# Requirement already satisfied: jsonschema==4.17.3 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 76)) (4.17.3)
# Requirement already satisfied: jupyter_client==8.2.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 77)) (8.2.0)
# Requirement already satisfied: jupyter_core==4.12.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 78)) (4.12.0)
# Requirement already satisfied: kaggle==1.5.15 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 79)) (1.5.15)
# Requirement already satisfied: keras==2.11.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 80)) (2.11.0)
# Requirement already satisfied: Keras-Applications==1.0.8 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 81)) (1.0.8)
# Requirement already satisfied: keras-nlp==0.5.2 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 82)) (0.5.2)
# Requirement already satisfied: Keras-Preprocessing==1.1.2 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 83)) (1.1.2)
# Requirement already satisfied: keras-tuner==1.3.5 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 84)) (1.3.5)
# Requirement already satisfied: kiwisolver==1.4.4 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 85)) (1.4.4)
# Requirement already satisfied: kt-legacy==1.0.5 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 86)) (1.0.5)
# Requirement already satisfied: langcodes==3.3.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 87)) (3.3.0)
# Requirement already satisfied: lazy_loader==0.2 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 88)) (0.2)
# Requirement already satisfied: libclang==16.0.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 89)) (16.0.0)
# Requirement already satisfied: Mako==1.2.4 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 90)) (1.2.4)
# Requirement already satisfied: Markdown==3.4.1 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 91)) (3.4.1)
# Requirement already satisfied: MarkupSafe==2.1.1 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 92)) (2.1.1)
# Requirement already satisfied: matplotlib==3.7.1 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 93)) (3.7.1)
# Requirement already satisfied: matplotlib-inline==0.1.6 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 94)) (0.1.6)
# Requirement already satisfied: mistune==3.0.1 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 95)) (3.0.1)
# Requirement already satisfied: mkl-fft==1.3.6 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 96)) (1.3.6)
# Requirement already satisfied: mkl-random==1.2.2 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 97)) (1.2.2)
# Requirement already satisfied: mkl-service==2.4.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 98)) (2.4.0)
# Requirement already satisfied: monotonic==1.6 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 99)) (1.6)
# Requirement already satisfied: mpmath==1.3.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 100)) (1.3.0)
# Requirement already satisfied: multidict==6.0.2 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 101)) (6.0.2)
# Requirement already satisfied: munkres==1.1.4 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 102)) (1.1.4)
# Requirement already satisfied: murmurhash==1.0.9 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 103)) (1.0.9)
# Requirement already satisfied: mypy-extensions==1.0.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 104)) (1.0.0)
# Requirement already satisfied: nbformat==5.9.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 105)) (5.9.0)
# Requirement already satisfied: nest-asyncio==1.5.6 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 106)) (1.5.6)
# Requirement already satisfied: networkx==3.1 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 107)) (3.1)
# Requirement already satisfied: nltk==3.8.1 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 108)) (3.8.1)
# Requirement already satisfied: numpy==1.24.3 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 109)) (1.24.3)
# Requirement already satisfied: oauthlib==3.2.2 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 110)) (3.2.2)
# Requirement already satisfied: opt-einsum==3.3.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 111)) (3.3.0)
# Requirement already satisfied: packaging==23.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 112)) (23.0)
# Requirement already satisfied: pandas==2.0.1 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 113)) (2.0.1)
# Requirement already satisfied: parso==0.8.3 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 114)) (0.8.3)
# Requirement already satisfied: pathspec==0.11.1 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 115)) (0.11.1)
# Requirement already satisfied: pathy==0.10.1 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 116)) (0.10.1)
# Requirement already satisfied: pexpect==4.8.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 117)) (4.8.0)
# Requirement already satisfied: pickleshare==0.7.5 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 118)) (0.7.5)
# Requirement already satisfied: Pillow==9.5.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 119)) (9.5.0)
# Requirement already satisfied: pip==23.0.1 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 120)) (23.0.1)
# Requirement already satisfied: pipreqs==0.4.13 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 121)) (0.4.13)
# Requirement already satisfied: platformdirs==3.8.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 122)) (3.8.0)
# Requirement already satisfied: ploomber-core==0.2.13 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 123)) (0.2.13)
# Requirement already satisfied: pooch==1.4.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 124)) (1.4.0)
# Requirement already satisfied: posthog==3.0.1 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 125)) (3.0.1)
# Requirement already satisfied: preshed==3.0.8 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 126)) (3.0.8)
# Requirement already satisfied: profanity-check==1.0.3 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 127)) (1.0.3)
# Requirement already satisfied: prompt-toolkit==3.0.38 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 128)) (3.0.38)
# Requirement already satisfied: protobuf==3.19.6 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 129)) (3.19.6)
# Requirement already satisfied: psutil==5.9.5 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 130)) (5.9.5)
# Requirement already satisfied: ptyprocess==0.7.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 131)) (0.7.0)
# Requirement already satisfied: pure-eval==0.2.2 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 132)) (0.2.2)
# Requirement already satisfied: pyarrow==12.0.1 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 133)) (12.0.1)
# Requirement already satisfied: pyasn1==0.4.8 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 134)) (0.4.8)
# Requirement already satisfied: pyasn1-modules==0.2.8 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 135)) (0.2.8)
# Requirement already satisfied: pycparser==2.21 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 136)) (2.21)
# Requirement already satisfied: pydantic==1.10.8 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 137)) (1.10.8)
# Requirement already satisfied: pydot==1.4.2 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 138)) (1.4.2)
# Requirement already satisfied: Pygments==2.15.1 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 139)) (2.15.1)
# Requirement already satisfied: PyJWT==2.4.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 140)) (2.4.0)
# Requirement already satisfied: pyOpenSSL==23.0.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 141)) (23.0.0)
# Requirement already satisfied: pyparsing==3.0.9 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 142)) (3.0.9)
# Requirement already satisfied: pyrsistent==0.19.3 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 143)) (0.19.3)
# Requirement already satisfied: PySocks==1.7.1 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 144)) (1.7.1)
# Requirement already satisfied: python-dateutil==2.8.2 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 145)) (2.8.2)
# Requirement already satisfied: python-slugify==8.0.1 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 146)) (8.0.1)
# Requirement already satisfied: pytz==2023.3 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 147)) (2023.3)
# Requirement already satisfied: PyWavelets==1.4.1 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 148)) (1.4.1)
# Requirement already satisfied: PyYAML==6.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 149)) (6.0)
# Requirement already satisfied: pyzmq==25.0.2 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 150)) (25.0.2)
# Requirement already satisfied: querystring-parser==1.2.4 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 151)) (1.2.4)
# Requirement already satisfied: regex==2023.6.3 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 152)) (2023.6.3)
# Requirement already satisfied: requests==2.29.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 153)) (2.29.0)
# Requirement already satisfied: requests-oauthlib==1.3.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 154)) (1.3.0)
# Requirement already satisfied: resnet-pytorch==0.2.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 155)) (0.2.0)
# Requirement already satisfied: rsa==4.7.2 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 156)) (4.7.2)
# Requirement already satisfied: scikit-image==0.21.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 157)) (0.21.0)
# Requirement already satisfied: scikit-learn==1.2.2 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 158)) (1.2.2)
# Requirement already satisfied: scipy==1.10.1 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 159)) (1.10.1)
# Requirement already satisfied: seaborn==0.12.2 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 160)) (0.12.2)
# Requirement already satisfied: setuptools==66.0.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 161)) (66.0.0)
# Requirement already satisfied: shellingham==1.5.1 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 162)) (1.5.1)
# Requirement already satisfied: six==1.16.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 163)) (1.16.0)
# Requirement already satisfied: sklearn-evaluation==0.12.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 164)) (0.12.0)
# Requirement already satisfied: smart-open==6.3.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 165)) (6.3.0)
# Requirement already satisfied: smmap==5.0.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 166)) (5.0.0)
# Requirement already satisfied: sniffio==1.3.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 167)) (1.3.0)
# Requirement already satisfied: spacy==3.5.3 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 168)) (3.5.3)
# Requirement already satisfied: spacy-legacy==3.0.12 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 169)) (3.0.12)
# Requirement already satisfied: spacy-loggers==1.0.4 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 170)) (1.0.4)
# Requirement already satisfied: sqlparse==0.4.4 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 171)) (0.4.4)
# Requirement already satisfied: srsly==2.4.6 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 172)) (2.4.6)
# Requirement already satisfied: stack-data==0.6.2 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 173)) (0.6.2)
# Requirement already satisfied: starlette==0.27.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 174)) (0.27.0)
# Requirement already satisfied: sympy==1.12 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 175)) (1.12)
# Requirement already satisfied: tabulate==0.9.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 176)) (0.9.0)
# Requirement already satisfied: tensorboard==2.11.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 177)) (2.11.0)
# Requirement already satisfied: tensorboard-data-server==0.6.1 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 178)) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit==1.6.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 179)) (1.6.0)
# Requirement already satisfied: tensorflow==2.11.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 180)) (2.11.0)
# Requirement already satisfied: tensorflow-addons==0.20.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 181)) (0.20.0)
# Requirement already satisfied: tensorflow-estimator==2.11.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 182)) (2.11.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.32.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 183)) (0.32.0)
# Requirement already satisfied: termcolor==2.1.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 184)) (2.1.0)
# Requirement already satisfied: text-unidecode==1.3 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 185)) (1.3)
# Requirement already satisfied: thinc==8.1.10 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 186)) (8.1.10)
# Requirement already satisfied: threadpoolctl==3.1.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 187)) (3.1.0)
# Requirement already satisfied: tifffile==2023.4.12 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 188)) (2023.4.12)
# Requirement already satisfied: tomli==2.0.1 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 189)) (2.0.1)
# Requirement already satisfied: torch==2.0.1 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 190)) (2.0.1)
# Requirement already satisfied: torchaudio==2.0.2 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 191)) (2.0.2)
# Requirement already satisfied: torchvision==0.15.2 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 192)) (0.15.2)
# Requirement already satisfied: tornado==6.3 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 193)) (6.3)
# Requirement already satisfied: tqdm==4.65.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 194)) (4.65.0)
# Requirement already satisfied: traitlets==5.9.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 195)) (5.9.0)
# Requirement already satisfied: typeguard==2.13.3 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 196)) (2.13.3)
# Requirement already satisfied: typer==0.7.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 197)) (0.7.0)
# Requirement already satisfied: typing_extensions==4.5.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 198)) (4.5.0)
# Requirement already satisfied: tzdata==2023.3 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 199)) (2023.3)
# Requirement already satisfied: unicodedata2==15.0.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 200)) (15.0.0)
# Requirement already satisfied: uritemplate==4.1.1 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 201)) (4.1.1)
# Requirement already satisfied: urllib3==1.26.15 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 202)) (1.26.15)
# Requirement already satisfied: wasabi==1.1.1 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 203)) (1.1.1)
# Requirement already satisfied: wcwidth==0.2.6 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 204)) (0.2.6)
# Requirement already satisfied: webencodings==0.5.1 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 205)) (0.5.1)
# Requirement already satisfied: websocket-client==1.6.1 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 206)) (1.6.1)
# Requirement already satisfied: Werkzeug==2.3.6 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 207)) (2.3.6)
# Requirement already satisfied: wheel==0.35.1 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 208)) (0.35.1)
# Requirement already satisfied: wrapt==1.14.1 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 209)) (1.14.1)
# Requirement already satisfied: yarg==0.1.9 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 210)) (0.1.9)
# Requirement already satisfied: yarl==1.8.1 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 211)) (1.8.1)
# Requirement already satisfied: zipp==3.15.0 in /usr/local/Caskroom/miniconda/base/envs/yputube_2/lib/python3.10/site-packages (from -r ../requirements.txt (line 212)) (3.15.0)

# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import os
import tensorflow as tf
import tqdm

# Preprocessing
import nltk
from profanity_check import predict_prob
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# 2023-07-02 21:56:51.976264: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Load the data
#
# Um die Daten über die Kaggel API zu laden muss ein API Token für die Authentifizierung hinterlegt werden.
#
# Dieser kann über diesen Link erstellt werden https://www.kaggle.com/settings/account.
#
# Das kaggel.json file muss im Ordner ~/.kaggle/kaggle.json.
#
# Versteckte Datein können bei Mac über  “Command” + “Shift” + “.” sichtbar gemacht werden.
#
# Weitere Informationen unter: https://www.kaggle.com/docs/api

# %%
# Download the Dataset from the Kaggel API

! kaggle datasets download -d datasnaek/youtube-new
# Out:
# Downloading youtube-new.zip to /Users/leamayer/Programmierung/YouTube_Stats_Forecasting/src
# 100%|███████████████████████████████████████▊| 200M/201M [00:21<00:00, 11.1MB/s]
# 100%|████████████████████████████████████████| 201M/201M [00:21<00:00, 9.92MB/s]

# %%
# Unzi download into folder

! unzip youtube-new.zip -d extracted_files
# Out:
# Archive:  youtube-new.zip
#   inflating: extracted_files/CA_category_id.json
#   inflating: extracted_files/CAvideos.csv
#   inflating: extracted_files/DE_category_id.json
#   inflating: extracted_files/DEvideos.csv
#   inflating: extracted_files/FR_category_id.json
#   inflating: extracted_files/FRvideos.csv
#   inflating: extracted_files/GB_category_id.json
#   inflating: extracted_files/GBvideos.csv
#   inflating: extracted_files/IN_category_id.json
#   inflating: extracted_files/INvideos.csv
#   inflating: extracted_files/JP_category_id.json
#   inflating: extracted_files/JPvideos.csv
#   inflating: extracted_files/KR_category_id.json
#   inflating: extracted_files/KRvideos.csv
#   inflating: extracted_files/MX_category_id.json
#   inflating: extracted_files/MXvideos.csv
#   inflating: extracted_files/RU_category_id.json
#   inflating: extracted_files/RUvideos.csv
#   inflating: extracted_files/US_category_id.json
#   inflating: extracted_files/USvideos.csv

# %%
# Copy english speacking contries to data folder

! cp extracted_files/CAvideos.csv ../Data/original_data/
! cp extracted_files/GBvideos.csv ../Data/original_data/
! cp extracted_files/USvideos.csv ../Data/original_data/

# %%
# remove folder with unneccesary files and zip

! rm -r extracted_files
! rm -r youtube-new.zip

# %% [markdown]
# # Enrichment of the Data

# %% [markdown]
# ## Add Missing Values or Subscription Details
#
# Das Abonnieren eines Kanals auf YouTube kann darauf hinweisen, wie die anderen Videos dieses Youtubers abschneiden. Daher ist die Abonnentenzahl ein Maß für die Reichweite des YouTubers. [1] Je nach Reichweite des Publikums, das durch ein Video erreicht werden kann, ist die Abonnentenzahl ein wichtiges Merkmal bei der Vorhersage der potenziellen Aufrufe eines Videos.
#
# Im Folgenden wurde die `YouTube Data API v3` von `www.googleapis.com` verwendet, um die Abonnentenzahl des Kanals zum df hinzuzufügen. Darüber hinaus wurde versucht die API zu verwenden um Missing Values im Dataframe zu ersetzen. Durch ein tägliches Limit bei den Request konnte dieser Ansatz jedoch nicht weiter verfolgt werden.
#
# [1] https://tuberanker.com/blog/what-are-the-benefits-of-subscribing-to-a-youtube-channel (04.06.23)

# %%
'''# The following youtube_authenticate function is available under this url: https://www.thepythoncode.com/article/using-youtube-api-in-python#google_vignette
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request

import urllib.parse as p
import re
import os
import pickle

SCOPES = ["https://www.googleapis.com/auth/youtube.force-ssl"]

def youtube_authenticate():
    os.environ["OAUTHLIB_INSECURE_TRANSPORT"] = "1"
    api_service_name = "youtube"
    api_version = "v3"
    client_secrets_file = "client_secret_883243427026-gmpvuoto8cd0gsl6djl80sesaa6b5jo0.apps.googleusercontent.com.json"
    creds = None
    # the file token.pickle stores the user's access and refresh tokens, and is
    # created automatically when the authorization flow completes for the first time
    if os.path.exists("token.pickle"):
        with open("token.pickle", "rb") as token:
            creds = pickle.load(token)
    # if there are no (valid) credentials availablle, let the user log in.
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(client_secrets_file, SCOPES)
            creds = flow.run_local_server(port=0)
        # save the credentials for the next run
        with open("token.pickle", "wb") as token:
            pickle.dump(creds, token)

    return build(api_service_name, api_version, credentials=creds)

# authenticate to YouTube API
youtube = youtube_authenticate()'''

# %%
'''# See the Youtube API Documentation for more insights: https://developers.google.com/youtube/v3/docs/subscriptions/list?hl=de&apix=true

def get_channel_details(youtube, **kwargs):

    request = youtube.channels().list(
        part="statistics", # just get stats
        **kwargs
    )
    response = request.execute()

    return response'''

# %%
'''# get subscription count and save it to the df

from tqdm import tqdm

for i in tqdm(range (0, len(df))):

    try:

        # get current channel Name
        channel_name = df.iloc[i]["channel_title"]

        # make API call to get channel infos
        response = get_channel_details(youtube, forUsername=channel_name)
        items = response.get("items")[0]
        statistics = items["statistics"]

        # get stats infos
        subscriberCount = statistics["subscriberCount"]

        # save subscriptions to df
        df.at[i,"subscriber_count"] = int(subscriberCount)

    except:

        df.at[i,"subscriber_count"] = np.NAN'''
# Out:
# 100%|██████████| 40881/40881 [22:59<00:00, 29.63it/s]

# %% [markdown]
# # Data Preprocessing
#
# Im Folgenden werden die Daten verarbeitet, indem diese bereinigt und mit NLP-Preprocessing Methoden bearbeitet werden. Damit soll die Qualität, die Aussagekraft und die politische Korrektheit der Texte gewehrleistet werden.
# Weitere modellspezifische Preprocessing-Schritte werden in den entsprechenden Notebooks durchgeführt.

# %% [markdown]
# ## Download Thumnails and add Path to jpg to the df
#
# Jedes YouTube-Video wird durch eine Thumbnail dargestellt, ein kleines Bild, das zusammen mit dem Titel und dem Kanal als "Cover" des Videos dient. Interessante und gut gestaltete Thumbnails ziehen Zuschauer an, während verwirrende und minderwertige Thumbnails die Zuschauer dazu bringen, woanders hinzuklicken. Ein Beweis dafür, wie wichtig ein guter Thumbnail ist: 90 % der erfolgreichsten YouTube-Videos haben Kunden-Thumbnails [2].
#
# Dementsprechend kann und wurde diese Funktion verwendet, um die Thumbnails zu laden. Jedoch werden diese Daten als bereits genannten Gründen nicht für die finalen Modelle verwendet.
#
# [2] YouTube Creator Academy. Lesson: Make click- able thumbnails. https://creatoracademy.youtube.com/page/lesson/thumbnails#yt-creators-strategies-5. (04.06.23)

# %%
'''# load thumbnail and save picture path in df
import urllib.request
from tqdm import tqdm
import os

def load_and_save_thumbnail(url, iterator):
    try:

        # get unique thumbnail id 
        splitted_words = url.split("/")
        thumbnail_id = splitted_words[4]

        # create filename to save thumbnail
        file_path = f"../Data/thumbnails/{thumbnail_id}.jpg"
        #df_w_jgp.at[iterator,"thumbnail_link"] = thumbnail_id

        # check if thumbnail is already downloaded
        if os.path.exists(file_path):
            pass
        else:
            # download and save thumbnail 
            urllib.request.urlretrieve(url, file_path)

    except urllib.error.URLError as e:

        df_w_jgp.at[iterator,"thumbnail_link"] = np.NAN
        # print(f"An error occurred: {e}")
        return None

for i in tqdm(range (0, len(df))):

    # get thumbnail url
    url = df.iloc[i]["thumbnail_link"]

    # safe thumnail and write path into df
    load_and_save_thumbnail(url, i)  '''
# Out:
# 100%|██████████| 500/500 [00:08<00:00, 58.34it/s]

# %% [markdown]
# ## Define Data Cleaning

# %%
def data_cleaning(df):

    # Drop Unnececary Columns

    df = df [["channel_title","tags","description", "title", "views", 'trending_date', 'video_id']]
    
    # Handling Missing Values

    if df.isnull().any().any() or df.isna().any().any():

        num = df.isnull().sum().sum() + df.isna().sum().sum() # Count Missing Values

        print(">>>",num, "Missing Values are beeing handeled")

        df = df.dropna() # Drop rows with missing values
        #df.fillna(value) # Fill missing values with a specific value

    else:
        print(">>> No Missing Values detected")
        
    # Remove Duplicate

    if df.duplicated().any():

        num = df.duplicated().sum() # Count Duplicates

        print(">>>",num, "Duplicates are beeing handeled")

        df.drop_duplicates()

    else:
        print(">>> No Duplicates detected")

    # Convert Data Types

    #print( df.dtypes ) # check data types

    # Convert 'trending_date' to year
    df["trending_date"] = df["trending_date"].str[6:].astype(int) # save trending year
    df = df.rename(columns={'trending_date': 'trending_year'})

    for column in df:

        # Check if column is of type bool
        if df[column].dtype == 'bool':
            df[column] = df[column].astype(int)

    # Check preprocessed data

    print(f">>> Updated Data Types \n {df.dtypes}")

    return df

# %% [markdown]
# ## Remove Profanity
#
# Damit das Modell nicht darauf trainiert wird, dass beleidigende Videoinhalte Views generieren können, wird an dieser Stelle ein Vortrainiertes Modell verwendet, um Videos mit solchen Inhalten zu identifizieren und zu entfernen. Mithilfe des Schwellenwertes kann die Stärke der Kontrolle abgepasst werden. Dieser wurde so festgelegt, dass versehentliche Aussortierungen möglichst verhindert werden können. Trotzdem gilt es, lieber Videos mit unfeindlichen Inhalten auszuschließen, als Videos mit feindlichen Inhalten zu behalten.

# %%
# Check text features for profanity and remove Videos with hate speech

threshold = 0.9 # Strength of the algorithm punishment (Higher -> more profanity needed to exculde Video)

def check_profanity(feature_df):

    before = feature_df.shape[0]

    for feature in feature_df:

        print(f"\n--- Checking {feature} feature for profanity ---\n")

        # for each row in dataframe column check if condition is true and save the index 
        # 0.0 -> no profanity / 1.0 -> profanity

        rows_to_drop = [index for index, f in enumerate(feature_df[feature]) if predict_prob([f]) > threshold]

        if len(rows_to_drop) >= 1:
            
            example = feature_df[feature][rows_to_drop[0]]
            print(f">>> Removed for example: {example}")

        try:
            feature_df = feature_df.drop(rows_to_drop, axis = 0)
        except:
            pass

    after = feature_df.shape[0]

    print(f">>> Removed {before-after} Videos containing possible profanity")

    return feature_df

# %% [markdown]
# ## Apply Functions and save partial DataFrame as CSV
#
# Hier werden die definierten Preprocessing Funktionen angewendet. Die bearbeiteten Daten werden anschließend jahres- und länderspezifisch abgespeichert. (Hinweis: Ganzen Output anzeigen lassen um Funktion der einzelnen Methoden nachzuvollziehen)

# %%
folder_path = "../Data/original_data"  # Path to original df
result_folder_path = "../Data/processed_data/"  # Path for processed df
iterator = 0

if os.path.exists(result_folder_path):

    # Iterate over files in the folder
    for file_name in os.listdir(folder_path):

        if file_name.endswith('.csv'):  # Process only CSV files
            
            file_path = os.path.join(folder_path, file_name)

            # Read the CSV file and create a DataFrame
            df = pd.read_csv(file_path, encoding='latin-1')

            print(f"\n--- Preprocessing {file_name} ---\n")

            df = data_cleaning(df)

            # --- Preprocess text features ---

            df[["channel_title","tags","title","description"]] = check_profanity(df[["channel_title","tags","title","description"]]) # check for profanity and remove rows accordingly

            #feature_df_preprocessed = apply_stemmer_stopwords(df[["channel_title","tags","title","description"]]) # remove stopwords and get stemm of words
            #df[["channel_title","tags","title","description"]] = feature_df_preprocessed

            # --- Group by trending year ---

            original_dataset = file_name[:-4]
            df_grouped = df.groupby('trending_year')

            # --- Save partial dataframes ---

            for group_name, group_data in df_grouped:

                # Save final df as csv
                csv_path = result_folder_path+original_dataset+"_"+str(group_name)+".csv"
                group_data.to_csv(csv_path, index=False)

    print(f"\n--- Preprocessing succesfull - Data has been saved to {csv_path} ---\n")
# Out:
# --- Preprocessing CAvideos.csv ---
#
# >>> 2592 Missing Values are beeing handeled
# >>> No Duplicates detected
# >>> Updated Data Types
#  channel_title    object
# tags             object
# description      object
# title            object
# views             int64
# trending_year     int64
# video_id         object
# dtype: object
#
# --- Checking channel_title feature for profanity ---
#
# >>> Removed for example: PowerfulJRE
#
# --- Checking tags feature for profanity ---
#
# >>> Removed for example: ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"idy"|"rhpc"|"dares"|"no truth"|"comments"|"comedy"|"funny"|"stupid"|"fail"
#
# --- Checking title feature for profanity ---
#
# >>> Removed for example: John Oliver video of Charlie Rose is extra creepy now
#
# --- Checking description feature for profanity ---
#
# >>> Removed for example: THIS VIDEO WILL MAKE YOU FORGET YOUR NAME ð®ðª\nPatreon https://www.patreon.com/cowchop\nSubscribe http://bit.ly/1RQtfNf Â \nCow Chop Merch: http://bit.ly/2dY0HrO  \nDiscuss: http://bit.ly/1qvrlLD Â \nTwitter: https://twitter.com/CowChop Â \nClick the link to sign up for Rooster Teeth FIRST and use the referral code COWCHOP https://goo.gl/NVZOT8\n\nYoutube has such a vast variety of great content! Why make Youtube great again when Youtube is already great?! See this video as an example. Where else can you go on an adventure through the deepest darkest weirdest side of video making and sharing, only here on this wonderful site will you get that experience, and now you can come along for the ride with us as we take you there!\n\nThe following is for those multicultural. \n\nHola gente. Es Trevor, tu narrador favorito aquÃ­ para darte otra gran historia que contar. Se trata de un pequeÃ±o amigo que conozco, un tipo pequeÃ±o muy especial que es extremadamente valiente y valiente. Todo comenzÃ³ cuando se liberÃ³ de su propio host, un intento de vivir por sÃ­ mismo. Para crear una vida y experimentar lo que todos buscamos, la felicidad. Lamentablemente, la pequeÃ±a etiqueta no pudo durar mucho, al menos no sin su host. Pero el caso es que el anfitriÃ³n no querÃ­a que le devolvieran la pequeÃ±a etiqueta. AsÃ­ que la etiqueta de la piel acaba de morir, gracias por sintonizar chicos.\n\nVideos\n\nFifty Shades Freed - https://youtu.be/nJCc5HRPxYA\nJustin Bieber ignoring fan - https://youtu.be/BzwQczH4wU4\nTanner Fox - https://youtu.be/ieUIoSzMDmY\nReaction To Justin Bieber - https://youtu.be/DVTAZDta_Uo\nIf you hate yourself watch this - https://youtu.be/O1GG2kOsAY8\nThis video will make you forget your name - https://youtu.be/1xEHvFmFGxI\n\n\nThank You ð®ðª\nAFTER WATCHING THIS YOU WILL HATE COW CHOP â¢ WRONG SIDE OF YOUTUBE
# >>> Removed 8 Videos containing possible profanity
#
# --- Preprocessing USvideos.csv ---
#
# >>> 1140 Missing Values are beeing handeled
# >>> 48 Duplicates are beeing handeled
# >>> Updated Data Types
#  channel_title    object
# tags             object
# description      object
# title            object
# views             int64
# trending_year     int64
# video_id         object
# dtype: object
#
# --- Checking channel_title feature for profanity ---
#
#
# --- Checking tags feature for profanity ---
#
# >>> Removed for example: ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"idy"|"rhpc"|"dares"|"no truth"|"comments"|"comedy"|"funny"|"stupid"|"fail"
#
# --- Checking title feature for profanity ---
#
# >>> Removed for example: When Someone Has A Crush on You | Lilly Singh
#
# --- Checking description feature for profanity ---
#
# \nFashion, beauty tips, celebrity style, pop culture, videos, and moreâeverything you need to be ahead of the trends.  Fashion starts here.\n\nHillary Clinton On Why Sheâs Not Running For President Again | Teen Vogueear old activist and Harvard sophomore Nadya Okomoto who ran for city council in Cambridge, Massachusetts; 10-year old Mari Copeny who made headlines for drawing attention to the water crisis in her hometown of Flint, Michigan; 19-year-old Syrian refugee and advocate for girls' education Muzoon Almellehan; and 18-year-old model, artist, designer and transgender activist Hunter Schafer. \n\nStill havenât subscribed to Teen Vogue on YouTube? âºâº http://bit.ly/tvyoutubesub
# >>> Removed 39 Videos containing possible profanity
#
# --- Preprocessing GBvideos.csv ---
#
# >>> 1224 Missing Values are beeing handeled
# >>> 169 Duplicates are beeing handeled
# >>> Updated Data Types
#  channel_title    object
# tags             object
# description      object
# title            object
# views             int64
# trending_year     int64
# video_id         object
# dtype: object
#
# --- Checking channel_title feature for profanity ---
#
# >>> Removed for example: Barcroft Animals
#
# --- Checking tags feature for profanity ---
#
# >>> Removed for example: christmas|"john lewis christmas"|"john lewis"|"christmas ad"|"mozthemonster"|"christmas 2017"|"christmas ad 2017"|"john lewis christmas advert"|"moz"
#
# --- Checking title feature for profanity ---
#
# >>> Removed for example: The Legend of Zelda: Breath of the Wild - Expansion Pass: DLC Pack 2 The Championsâ Ballad Trailer
#
# --- Checking description feature for profanity ---
#
# >>> Removed for example: This is my raw 100% raw opinion on Star Wars: The Last Jedi.\nI live and bleed Star Wars, so this is just my viewpoint on the latest installment. Feel free to comment & we can constructively talk.
# >>> Removed 54 Videos containing possible profanity
#
# --- Preprocessing succesfull - Data has been saved to ../Data/processed_data/GBvideos_12.csv ---
